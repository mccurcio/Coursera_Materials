# %% [markdown]
# ### Python for Everybody Regular Expressions: Practical Applications
#
# https://www.freecodecamp.org/learn/scientific-computing-with-python/python-for-everybody/relational-databases-relationship-building

# %% [markdown]
# #### Relational Databases: Relationship Building
#
# Q. What does the INSERT command do in SQL?
#
# A. It defines a new row by listing the fields we want to include followed by the values we want placed in the new row.

# %% [markdown]
# #### Relational Databases: Join Operation
#
# Q. When using a JOIN clause in an SQL statement, what does ON do?
#
# A.

# %%
import sqlite3
from sqlite3 import connect

# Test db = 'Sample-SQL-File-100-Rows.sql'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-f9731b8ad843> in <module>
#       6 import pandas as pd
#       7 import sqlite3
# ----> 8 import sqlalchemy
#       9
#      10 try:
#
# ModuleNotFoundError: No module named 'sqlalchemy'

# %%
#Import library
from IPython.display import Image
# Load image from local storage
Image(filename = "join_image.png", width = 733, height = 452)
